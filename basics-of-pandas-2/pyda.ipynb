# %% [markdown]
# Data frame creation

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Making dataframe from dataset

# %%
df=pd.read_csv("Iris.csv")
daf=pd.DataFrame(df)
daf
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
arr=np.arange(1,5)
a=pd.Series(arr)
daf=daf.assign(number=a)
daf
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  number
# 0       Iris-setosa     1.0
# 1       Iris-setosa     2.0
# 2       Iris-setosa     3.0
# 3       Iris-setosa     4.0
# ...

# %% [markdown]
# MATHS

# %% [markdown]
# to calculate sum

# %%
daf['number'].sum()
# Out:
# np.float64(10.0)

# %% [markdown]
# no of rows

# %%
daf['SepalLengthCm'].count().item()
# Out:
# 150

# %% [markdown]
# mean

# %%
daf['SepalLengthCm'].mean().item()
# Out:
# 5.843333333333334

# %% [markdown]
# sum

# %%
daf['SepalLengthCm'].sum().item()
# Out:
# 876.5

# %% [markdown]
# std

# %%
daf['SepalLengthCm'].std().item()
# Out:
# 0.828066127977863

# %%
daf['SepalLengthCm'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: SepalLengthCm, dtype: float64

# %% [markdown]
# operations on row

# %%
daf['SepalLengthCm']+daf['SepalWidthCm']
# Out:
# 0      8.6
# 1      7.9
# 2      7.9
# 3      7.7
# 4      8.6
#       ...
# 145    9.7
# 146    8.8
# 147    9.5
# 148    9.6
# 149    8.9
# Length: 150, dtype: float64

# %% [markdown]
# value_count() and value_count(normalize=True)

# %% [markdown]
# sort

# %% [markdown]
# sort  by one column

# %%
daf.sort_values(by='SepalLengthCm')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 8      9            4.4           2.9            1.4           0.2
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 117  118            7.7           3.8            6.7           2.2
# 118  119            7.7           2.6            6.9           2.3
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species  number
# 13      Iris-setosa     NaN
# 8       Iris-setosa     NaN
# 42      Iris-setosa     NaN
# 38      Iris-setosa     NaN
# ...

# %% [markdown]
# descending

# %%
daf.sort_values(by='SepalLengthCm', ascending=False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# ..   ...            ...           ...            ...           ...
# 41    42            4.5           2.3            1.3           0.3
# 42    43            4.4           3.2            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 38    39            4.4           3.0            1.3           0.2
# 13    14            4.3           3.0            1.1           0.1
#
#             Species  number
# 131  Iris-virginica     NaN
# 122  Iris-virginica     NaN
# 118  Iris-virginica     NaN
# 117  Iris-virginica     NaN
# ...

# %% [markdown]
# inplace

# %%
daf.sort_values(by='SepalLengthCm', ascending=False,inplace=True)
daf
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 131  132            7.9           3.8            6.4           2.0
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# ..   ...            ...           ...            ...           ...
# 41    42            4.5           2.3            1.3           0.3
# 42    43            4.4           3.2            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 38    39            4.4           3.0            1.3           0.2
# 13    14            4.3           3.0            1.1           0.1
#
#             Species  number
# 131  Iris-virginica     NaN
# 122  Iris-virginica     NaN
# 118  Iris-virginica     NaN
# 117  Iris-virginica     NaN
# ...
